# %%
import numpy as np
import pandas as pd
from scipy.sparse import hstack, csr_matrix
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import TimeSeriesSplit, cross_val_score, GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import matplotlib.pyplot as plt
import pickle
import warnings
import eli5
warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv('train_sessions.csv',
                       index_col='session_id', parse_dates=['time1'])
test_df = pd.read_csv('test_sessions.csv',
                      index_col='session_id', parse_dates=['time1'])

train_df.sort_values('time1', inplace=True)

y_train = train_df.target

train_df.drop('target', axis = 1, inplace=True)

# %%
with open('site_dic.pkl', 'rb') as f:
        site2id = pickle.load(f)
        
id2site = {v:k for (k, v) in site2id.items()}

id2site[0] = 'unknown'

# %% [markdown]
# **Тесты**

# %%
sites = ['site%s' % i for i in range(1, 11)]

# %%
train_df_site = train_df[sites].fillna(0).apply(lambda x: x.map(id2site))
import re
train_df_site = train_df_site.applymap(lambda site: re.sub("^\S*?\.*?www\S*?\.", '', site))

# %%
train_sessions = train_df_site.apply(lambda row:' '.join([i for i in row]), axis=1).tolist()

# %%
idf_vec = TfidfVectorizer(ngram_range=(1,5), max_features=50000, tokenizer = lambda s: s.split())
train_tfidf = idf_vec.fit_transform(train_sessions)

# %% [markdown]
# **Конец тестов**

# %%
sites = ['site%s' % i for i in range(1, 11)]

train_sessions = train_df[sites].fillna(0).astype('int').apply(lambda row: 
                                                     ' '.join([id2site[i] for i in row]), axis=1).tolist()
test_sessions = test_df[sites].fillna(0).astype('int').apply(lambda row: 
                                                     ' '.join([id2site[i] for i in row]), axis=1).tolist()

idf_vec = TfidfVectorizer(ngram_range=(1,5), max_features=50000, tokenizer = lambda s: s.split())
train_tfidf = idf_vec.fit_transform(train_sessions)
test_tfidf = idf_vec.transform(test_sessions)

# %%
idx_splite = train_df.shape[0]

time_splite = TimeSeriesSplit(n_splits=10)

logit = LogisticRegression(C=1, solver='liblinear', random_state=17)

cross = cross_val_score(logit, train_tfidf, y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)

res = {}
res['n_1'] = {'scores' : cross, 'mean' : cross.mean(), 'sd' : cross.std()}

# %%
# Что бы посмотреть значимость

# logit.fit(train_tfidf, y_train)

# eli5.show_weights(estimator=logit, feature_names = idf_vec.get_feature_names(), top = 100, include_styles = False)

# %%
full_df = pd.concat([train_df, test_df]).reset_index(drop = True)
full_df[['time' + str(x) for x in range(1, 11)]] = full_df[['time' + str(x) for x in range(1, 11)]].apply(pd.to_datetime)
time_features = pd.DataFrame(index=full_df.index)
time_features['hour'] = full_df.time1.dt.hour

cross = cross_val_score(logit, hstack([train_tfidf, time_features.values[:idx_splite]]), y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)
res['n_2'] = {'scores' : cross, 'mean' : cross.mean(), 'sd' : cross.std()}

# %%
stnd = StandardScaler()

cross = cross_val_score(logit, hstack([train_tfidf, 
                                       stnd.fit_transform(time_features.values[:idx_splite])]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)
res['n_3'] = {'scores' : cross, 'mean' : cross.mean(), 'sd' : cross.std()}

# %%
time_features['morning'] = ((time_features.hour >= 7) & (time_features.hour <= 11)).astype('int')
time_features['day'] = ((time_features.hour >= 12) & (time_features.hour <= 18)).astype('int')
time_features['evening'] = ((time_features.hour >= 19) & (time_features.hour <= 23)).astype('int')
time_features['night'] = ((time_features.hour >= 0) & (time_features.hour <= 6)).astype('int')

cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features.values[:idx_splite]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)
res['n_4'] = {'scores' : cross, 'mean' : cross.mean(), 'sd' : cross.std()}

# %%
cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features.drop('hour', axis = 1).values[:idx_splite]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)
res['n_5'] = {'scores' : cross, 'mean' : cross.mean(), 'sd' : cross.std()}

# %%
time_features = pd.concat([time_features, pd.get_dummies(time_features.hour, prefix = 'hour')], axis = 1)

cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features.drop('hour', axis = 1).values[:idx_splite]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)
res['n_6'] = {'scores' : cross, 'mean' : cross.mean(), 'sd' : cross.std()}

# %%
import seaborn as sns
plt.subplots(1, 2, figsize = (12, 6)) 

plt.subplot(1, 2, 1)
sns.countplot(pd.to_datetime(train_df.time1).dt.hour[y_train == 1])
plt.title("Alice")
plt.xlabel('Session start hour');

plt.subplot(1, 2, 2)
sns.countplot(pd.to_datetime(train_df.time1).dt.hour[y_train == 0])
plt.title("not Alice")
plt.xlabel('Session start hour');

# %%
cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features[['morning', 'day', 'evening', 'hour_8', 'hour_10', 'hour_14', 'hour_23']].values[:idx_splite, :]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)
res['n_7'] = {'scores' : cross, 'mean' : cross.mean(), 'sd' : cross.std()}

# %%
# Эти фичи выловил с перебора, но в целом видна логика. Выбор пал на те фичи, которые сильнее всего разделяют Алису и не Алису
# Результат такого сабмита - 0.953
time_features = time_features[['morning', 'day', 'evening', 'hour_8', 'hour_10', 'hour_14', 'hour_23']]
full_df.time1 = pd.to_datetime(full_df.time1)
time_features['month'] = full_df.time1.dt.month

# %%
plt.subplots(1, 2, figsize = (18, 6)) 

plt.subplot(2, 2, 1)
sns.countplot(pd.to_datetime(train_df.time1).dt.month[y_train == 1])
plt.title("Alice")
plt.xlabel('Session start hour');

plt.subplot(2, 2, 2)
sns.countplot(pd.to_datetime(train_df.time1).dt.month[y_train == 0])
plt.title("not Alice")
plt.xlabel('Session start hour');

plt.subplot(2, 2, 3)
sns.countplot((pd.to_datetime(train_df.time1).dt.year * 100 + pd.to_datetime(train_df.time1).dt.month)[y_train == 1])
plt.title("Alice")
plt.xlabel('Session start hour');

plt.subplot(2, 2, 4)
sns.countplot((pd.to_datetime(train_df.time1).dt.year * 100 + pd.to_datetime(train_df.time1).dt.month)[y_train == 0])
plt.title("not Alice")
plt.xticks(rotation = -45)
plt.xlabel('Session start hour');

# %%
def compare(new_cross, res_num):
    tmp = pd.DataFrame({res_num : res[res_num]['scores'], 
                  'new' : new_cross, 
                  'compare' : res[res_num]['scores'] < new_cross})
    print('сравнение батчей \n', tmp)
    print('\nСредние:\n', 'Новое:', new_cross.mean().round(5), '\tСтарое: ', res[res_num]['scores'].mean().round(5))
    print('\nSD:\n', 'Новое:', new_cross.std().round(5), '\tСтарое: ', res[res_num]['scores'].std().round(5))
    
cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features.values[:idx_splite, :]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)

compare(cross, 'n_7')
# Out:
# сравнение батчей
#          n_7       new  compare
# 0  0.891923  0.884977    False
# 1  0.848147  0.849604     True
# 2  0.938833  0.933151    False
# 3  0.942345  0.943029     True
# 4  0.936458  0.936568     True
# 5  0.959577  0.959332    False
# 6  0.945965  0.945161    False
# 7  0.946413  0.946308    False
# 8  0.961120  0.961412     True
# 9  0.962269  0.962114    False
#
# Средние:
#  Новое: 0.93217 	Старое:  0.9333
#
# SD:
#  Новое: 0.0347 	Старое:  0.03424

# %%
time_features['year'] = stnd.fit_transform(full_df.time1.dt.year.astype('float64').values.reshape(-1, 1))
time_features['yyyymm'] = time_features.year * 100 + time_features.month
time_features['yyyymm'] = stnd.fit_transform(time_features.yyyymm.values.reshape(-1, 1))

cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features.drop(['year', 'month'], axis =1 ).values[:idx_splite, :]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)

compare(cross, 'n_7')
res['n_8'] = {'scores' : cross, 'mean' : cross.mean(), 'sd' : cross.std(), 'comment' : 'добавил yyyymm'}
# Out:
# сравнение батчей
#          n_7       new  compare
# 0  0.891923  0.893634     True
# 1  0.848147  0.850593     True
# 2  0.938833  0.960430     True
# 3  0.942345  0.943758     True
# 4  0.936458  0.936886     True
# 5  0.959577  0.959611     True
# 6  0.945965  0.945332    False
# 7  0.946413  0.946157    False
# 8  0.961120  0.960671    False
# 9  0.962269  0.962290     True
#
# Средние:
#  Новое: 0.93594 	Старое:  0.9333
#
# SD:
#  Новое: 0.03434 	Старое:  0.03424

# %%
# Для биннинга не нахожу ничегоподходящего
time_features = pd.concat([time_features, pd.get_dummies(time_features.month, prefix = 'month')], axis = 1)

cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features.drop(['year', 'month'], axis = 1).values[:idx_splite, :]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)

compare(cross, 'n_8')
# Out:
# сравнение батчей
#          n_8       new  compare
# 0  0.893634  0.877292    False
# 1  0.850593  0.855743     True
# 2  0.960430  0.960840     True
# 3  0.943758  0.944529     True
# 4  0.936886  0.937838     True
# 5  0.959611  0.959114    False
# 6  0.945332  0.945745     True
# 7  0.946157  0.945259    False
# 8  0.960671  0.960703     True
# 9  0.962290  0.963391     True
#
# Средние:
#  Новое: 0.93505 	Старое:  0.93594
#
# SD:
#  Новое: 0.03556 	Старое:  0.03434

# %%
time_features['summer'] = time_features.month.isin([5,6,7,8]).astype('int')
time_features['september'] = (time_features.month == 9).astype('int')

cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features.drop(['year', 'month'], axis = 1).values[:idx_splite, :]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)

compare(cross, 'n_8')
# Out:
# сравнение батчей
#          n_8       new  compare
# 0  0.893634  0.880241    False
# 1  0.850593  0.856144     True
# 2  0.960430  0.960751     True
# 3  0.943758  0.944414     True
# 4  0.936886  0.938015     True
# 5  0.959611  0.959149    False
# 6  0.945332  0.945476     True
# 7  0.946157  0.945697    False
# 8  0.960671  0.960964     True
# 9  0.962290  0.963306     True
#
# Средние:
#  Новое: 0.93542 	Старое:  0.93594
#
# SD:
#  Новое: 0.03501 	Старое:  0.03434

# %%
# Добавление yyyymm подняло скор на публике до 0.954

# %% [markdown]
# **Лаг по времени добавлю**

# %%
# Из месяцов выстрелило только yyyymm, потому что явно видкн тренд к увеличению фрода
time_features = time_features.drop(['month', 'year', 'summer', 'september'], axis = 1)

sites = ['site' + str(x) for x in range(1, 11)]
full_df[sites] = full_df[sites].fillna(0)

times = ['time' + str(x) for x in range(1, 11)]
time_features['max'] = full_df[times].max(axis = 1)
time_features['min'] = full_df[times].min(axis = 1)
time_features['seconds'] = (time_features['max'] - time_features['min']).dt.seconds
time_features['counts'] = full_df[sites].apply(lambda x: np.sum(x != 0), axis = 1)
time_features['n_unique'] = full_df[sites].apply(lambda x: x[x != 0].nunique(), axis = 1)
time_features['mean_seconds'] = time_features.seconds / time_features['counts']

# %%
time_features['seconds_s'] = time_features.seconds / time_features.seconds.max()
time_features['counts_s'] = time_features['counts'] / time_features['counts'].max()
time_features['n_unique_s'] = time_features.n_unique / time_features.n_unique.max()
time_features['mean_seconds_s'] = time_features.mean_seconds / time_features.mean_seconds.max()

# %%
cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features.drop(['min', 'max', 'seconds', 'counts', 'n_unique', 'mean_seconds'], axis = 1).values[:idx_splite, :]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)

compare(cross, 'n_8')
# Out:
# сравнение батчей
#          n_8       new  compare
# 0  0.893634  0.881681    False
# 1  0.850593  0.852853     True
# 2  0.960430  0.960681     True
# 3  0.943758  0.945046     True
# 4  0.936886  0.937303     True
# 5  0.959611  0.960512     True
# 6  0.945332  0.948507     True
# 7  0.946157  0.946748     True
# 8  0.960671  0.961639     True
# 9  0.962290  0.961997    False
#
# Средние:
#  Новое: 0.9357 	Старое:  0.93594
#
# SD:
#  Новое: 0.03572 	Старое:  0.03434

# %%
cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features.drop(['min', 'max', 'seconds', 'counts', 'n_unique', 'mean_seconds', 'n_unique_s', 'mean_seconds_s'], axis = 1).values[:idx_splite, :]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)

compare(cross, 'n_8')
res['n_9'] = {'scores' : cross, 'mean' : cross.mean(), 'sd' : cross.std(), 'comment' : 'добавил количество секунд'}

time_features = time_features.drop(['min', 'max', 'seconds', 'counts', 'n_unique', 'mean_seconds', 'n_unique_s', 'mean_seconds_s'], axis = 1)
# Out:
# сравнение батчей
#          n_8       new  compare
# 0  0.893634  0.889061    False
# 1  0.850593  0.852897     True
# 2  0.960430  0.960902     True
# 3  0.943758  0.945167     True
# 4  0.936886  0.937002     True
# 5  0.959611  0.960559     True
# 6  0.945332  0.948489     True
# 7  0.946157  0.946798     True
# 8  0.960671  0.961933     True
# 9  0.962290  0.962393     True
#
# Средние:
#  Новое: 0.93652 	Старое:  0.93594
#
# SD:
#  Новое: 0.03472 	Старое:  0.03434

# %%
logit.fit(hstack([train_tfidf, 
                 time_features.values[:idx_splite, :]]),
         y_train)
pred = logit.predict_proba(hstack([test_tfidf, 
                                   time_features.values[idx_splite:, :]]))[:, 1]
pd.DataFrame(pred, index=np.arange(1, pred.shape[0] + 1), columns=['target']).\
        to_csv('subs/sub_5.csv', index_label="session_id")

# %% [markdown]
# **Дни недели**

# %%
plt.subplots(1, 2, figsize = (18, 6)) 

plt.subplot(1, 2, 1)
sns.countplot(pd.to_datetime(train_df.time1).dt.weekday[y_train == 1])
plt.title("Alice")
plt.xlabel('Session start hour');

plt.subplot(1, 2, 2)
sns.countplot(pd.to_datetime(train_df.time1).dt.weekday[y_train == 0])
plt.title("not Alice")
plt.xlabel('Session start hour');

# %%
time_features['wedsday'] = (full_df.time1.dt.weekday == 2).astype('int')
time_features['weekend'] = full_df.time1.dt.weekday.isin([5,6]).astype('int')

cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features.values[:idx_splite, :]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)

compare(cross, 'n_9')
res['n_9'] = {'scores' : cross, 'mean' : cross.mean(), 'sd' : cross.std(), 'comment' : 'добавил среду и выходной'}
# Out:
# сравнение батчей
#          n_9       new  compare
# 0  0.889061  0.917074     True
# 1  0.852897  0.902246     True
# 2  0.960902  0.902834    False
# 3  0.945167  0.958925     True
# 4  0.937002  0.947263     True
# 5  0.960559  0.976622     True
# 6  0.948489  0.948787     True
# 7  0.946798  0.960665     True
# 8  0.961933  0.802309    False
# 9  0.962393  0.968927     True
#
# Средние:
#  Новое: 0.92857 	Старое:  0.93652
#
# SD:
#  Новое: 0.04907 	Старое:  0.03472

# %%
logit.fit(hstack([train_tfidf, 
                 time_features.values[:idx_splite, :]]),
         y_train)
pred = logit.predict_proba(hstack([test_tfidf, 
                                   time_features.values[idx_splite:, :]]))[:, 1]
pd.DataFrame(pred, index=np.arange(1, pred.shape[0] + 1), columns=['target']).\
        to_csv('subs/sub_6.csv', index_label="session_id")

# Збс. Результат - 0.956

# %%
time_features['unknown_site'] = full_df[sites].apply(lambda x: 1 if (x == 0).sum() == 0 else 1, axis = 1)

cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features.values[:idx_splite, :]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)

compare(cross, 'n_9')
# Out:
# сравнение батчей
#          n_9       new  compare
# 0  0.917074  0.917026    False
# 1  0.902246  0.902150    False
# 2  0.902834  0.902226    False
# 3  0.958925  0.958365    False
# 4  0.947263  0.947386     True
# 5  0.976622  0.976636     True
# 6  0.948787  0.947942    False
# 7  0.960665  0.960700     True
# 8  0.802309  0.803005     True
# 9  0.968927  0.968994     True
#
# Средние:
#  Новое: 0.92844 	Старое:  0.92857
#
# SD:
#  Новое: 0.04887 	Старое:  0.04907

# %%
alise_site = pd.Series(train_df.loc[y_train == 1, sites].fillna(0).values.flatten()).value_counts()
not_alise_site = pd.Series(train_df.loc[y_train == 0, sites].fillna(0).values.flatten()).value_counts()

print('Топ сайты для не Алисы', 
      set(not_alise_site.index[:15].values.tolist()) - set(alise_site.index[:15].values.tolist()))

print('Топ сайты для Алисы',
     set(alise_site.index[:15].values.tolist()) - set(not_alise_site.index[:15].values.tolist()))
# Out:
# Топ сайты для не Алисы {0.0, 39.0, 167.0, 778.0, 780.0, 812.0, 782.0, 52.0, 55.0, 570.0}
# Топ сайты для Алисы {33.0, 35.0, 37.0, 75.0, 76.0, 77.0, 879.0, 81.0, 82.0, 881.0}

# %%
#time_features['top_alise'] = full_df[sites].apply(lambda x: x.isin([33.0, 35.0, 37.0, 75.0, 76.0, 77.0, 81.0, 82.0, 879.0, 881.0]).sum(), axis = 1)
#time_features['top_not_alise'] = full_df[sites].apply(lambda x: x.isin([39.0, 52.0, 55.0, 167.0, 570.0, 778.0, 780.0, 782.0, 812.0]).sum(), axis = 1)

cross = cross_val_score(logit, hstack([train_tfidf, 
                                       time_features.values[:idx_splite, :]]), 
                        y_train, cv = time_splite, scoring='roc_auc', n_jobs=4)

compare(cross, 'n_9')
res['n_10'] = {'scores' : cross, 'mean' : cross.mean(), 'sd' : cross.std(), 'comment' : 'добавил популярные сайты'}
# Out:
# сравнение батчей
#          n_9       new  compare
# 0  0.917074  0.921022     True
# 1  0.902246  0.909873     True
# 2  0.902834  0.906422     True
# 3  0.958925  0.962755     True
# 4  0.947263  0.948438     True
# 5  0.976622  0.976634     True
# 6  0.948787  0.953872     True
# 7  0.960665  0.959625    False
# 8  0.802309  0.828061     True
# 9  0.968927  0.970269     True
#
# Средние:
#  Новое: 0.9337 	Старое:  0.92857
#
# SD:
#  Новое: 0.04237 	Старое:  0.04907

# %%
logit.fit(hstack([train_tfidf, 
                 time_features.values[:idx_splite, :]]),
         y_train)
pred = logit.predict_proba(hstack([test_tfidf, 
                                   time_features.values[idx_splite:, :]]))[:, 1]
pd.DataFrame(pred, index=np.arange(1, pred.shape[0] + 1), columns=['target']).\
        to_csv('subs/sub_8.csv', index_label="session_id")

# Еще улучшил результат. 0.958
